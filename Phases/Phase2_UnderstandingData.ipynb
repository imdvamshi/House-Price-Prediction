# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append("..")
from src.load_data import load_data

# %%
data = load_data()
data.head()
# Out:
#    Unnamed: 0            title    location  price(L)  rate_persqft  \
# 0           0  3 BHK Apartment    Nizampet    108.00          6000
# 1           1  3 BHK Apartment  Bachupally     85.80          5500
# 2           2  2 BHK Apartment    Dundigal     55.64          5200
# 3           3  2 BHK Apartment    Pocharam     60.48          4999
# 4           4  3 BHK Apartment      Kollur    113.00          5999
#
#    area_insqft     building_status
# 0         1805  Under Construction
# 1         1560  Under Construction
# 2         1070  Under Construction
# 3         1210  Under Construction
# 4         1900  Under Construction

# %% [markdown]
# - Number of rows : 3660
# - Number of columns : 7
# - Missing Values : No
# - Duplicate rows : No
# - Outliers : Yes
# - Data Type Issues : Yes

# %%
data.shape
# Out:
# (3660, 7)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3660 entries, 0 to 3659
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       3660 non-null   int64
#  1   title            3660 non-null   str
#  2   location         3660 non-null   str
#  3   price(L)         3660 non-null   float64
#  4   rate_persqft     3660 non-null   int64
#  5   area_insqft      3660 non-null   int64
#  6   building_status  3660 non-null   str
# dtypes: float64(1), int64(3), str(3)
# memory usage: 200.3 KB

# %%
data.describe(include='all')
# Out:
#         Unnamed: 0             title    location     price(L)   rate_persqft  \
# count   3660.00000              3660        3660  3660.000000    3660.000000
# unique         NaN                25         359          NaN            NaN
# top            NaN  Residential Plot  Mirkhanpet          NaN            NaN
# freq           NaN              1617         165          NaN            NaN
# mean    1829.50000               NaN         NaN   109.624350    5165.003005
# std     1056.69532               NaN         NaN   197.596948    5316.490320
# min        0.00000               NaN         NaN     1.320000     125.000000
# 25%      914.75000               NaN         NaN    26.137500    1555.000000
# 50%     1829.50000               NaN         NaN    61.130000    4703.000000
# 75%     2744.25000               NaN         NaN   116.000000    6800.000000
# max     3659.00000               NaN         NaN  3600.000000  112474.000000
#
#          area_insqft building_status
# count    3660.000000            3660
# unique           NaN               4
# top              NaN             New
# freq             NaN            1378
# mean     2023.506284             NaN
# std      1829.832163             NaN
# min       118.000000             NaN
# 25%      1280.000000             NaN
# 50%      1620.000000             NaN
# 75%      2080.000000             NaN
# max     45000.000000             NaN

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# title              0
# location           0
# price(L)           0
# rate_persqft       0
# area_insqft        0
# building_status    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.boxplot(data=data,x='price(L)')
plt.show()

# %%
sns.boxplot(data=data,x='rate_persqft')
plt.show()

# %%
sns.boxplot(data=data,x='area_insqft')
plt.show()
